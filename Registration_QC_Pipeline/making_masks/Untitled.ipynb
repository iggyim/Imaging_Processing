# %%
import pandas as pd
markers = pd.read_csv('clean_markers.csv')

# %%
markers
# Out:
#     channel_number  cycle_number marker_name Filter  excitation_wavelength  \
# 0                1             0       DNA_0   DAPI                    405
# 1                2             1         NWS    GFP                    488
# 2                3             1        VSVG    RFP                    561
# 3                4             1        FLAG    Cy5                    637
# 4                5             2         HSV    GFP                    488
# 5                6             2           C    RFP                    561
# 6                7             2           S    Cy5                    637
# 7                8             3       Ollas    GFP                    488
# 8                9             3        GFAP    RFP                    561
# 9               10             3        NeuN    Cy5                    637
# 10              11             4       pRPS6    GFP                    488
# ...
